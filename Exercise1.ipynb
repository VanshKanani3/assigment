# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
chipotle_df=pd.read_csv("chipotle.tsv",sep="\t")  
chipotle_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df = chipotle_df

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipotle_df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipotle_df.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipotle_df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipotle_df.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
order = chipotle_df.groupby("item_name")
order["item_name"].count().sort_values(ascending = False).head()
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: item_name, dtype: int64

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
order["item_name"].count().sort_values(ascending = False).head(1)
# Out:
# item_name
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
a = chipotle_df.groupby("choice_description")
a["choice_description"].count().sort_values(ascending = False).head()
# Out:
# choice_description
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipotle_df.quantity.sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipotle_df["item_price"]=chipotle_df["item_price"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 chipotle_df["item_price"]=chipotle_df["item_price"].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
chipotle_df["item_name"].nunique()
# Out:
# 50

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipotle_df['item_price'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Step 14. Find the total revenue of item price in the dataset?

# %%
chipotle_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
y=chipotle_df.groupby("item_price").sum()
y
# Out:
# C:\Users\Vansh Kanani\AppData\Local\Temp\ipykernel_20956\4021108569.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   y=chipotle_df.groupby("item_price").sum()
#             order_id  quantity
# item_price
# $1.09          84666       106
# $1.25         265250       264
# $1.50         130856       117
# $1.69          82040        99
# $1.99           1793         1
# ...              ...       ...
# $8.75         708246       730
# $8.90          16985        40
# $8.99         186817       246
# $9.25         366496       398
# $9.39          20992        17
#
# [78 rows x 2 columns]

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipotle_df[["item_price"]].mean(axis=1)
# Out:
# C:\Users\Vansh Kanani\AppData\Local\Temp\ipykernel_20956\60907393.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   chipotle_df[["item_price"]].mean(axis=1)
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4617   NaN
# 4618   NaN
# 4619   NaN
# 4620   NaN
# 4621   NaN
# Length: 4622, dtype: float64

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
v=chipotle_df.groupby("item_name").count()
v
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# 6 Pack Soft Drink                            54        54                  54
# Barbacoa Bowl                                66        66                  66
# Barbacoa Burrito                             91        91                  91
# Barbacoa Crispy Tacos                        11        11                  11
# Barbacoa Salad Bowl                          10        10                  10
# Barbacoa Soft Tacos                          25        25                  25
# Bottled Water                               162       162                   0
# Bowl                                          2         2                   2
# Burrito                                       6         6                   6
# Canned Soda                                 104       104                 104
# Canned Soft Drink                           301       301                 301
# ...
